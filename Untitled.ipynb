# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from GA_SnakSack import GA_SnakSack

# %%
x = GA_SnakSack()

a,b,c,d,e = x.ga(size_generation=500,
         size_population=100,
         max_weight=100,
         max_coust=50,
         towns_list='./pontos.txt',
         weight_list='./prize_penalty.txt',
         begin_deposit=0)
# Out:
# 0
# /home/killdary/Documentos/estudos/mestrado/aulas/Projeto/Dissertação/genetic_algorithm_route_calculation/GA_SnakSack.py:329: FutureWarning: in the future negative indices will not be ignored by `numpy.delete`.
#   x = np.delete(i,[0, -1])
# 10
# 20
# 30
# 40
# 68.93526501
# 37
# 50
# 60
# 70
# 80
# 90
# 68.93526501
# 87
# 100
# 110
# 120
# 130
# 140
# 68.93526501
# 137
# 150
# 160
# 170
# 180
# 190
# 54.19464288
# 23
# 200
# 210
# 220
# 230
# 240
# 54.19464288
# 73
# 250
# 260
# 270
# 280
# 290
# 54.19464288
# 123
# 300
# 310
# 320
# 330
# 340
# 54.19464288
# 173
# 350
# 360
# 370
# 380
# 390
# 51.00223658
# 22
# 400
# 410
# 420
# 430
# 440
# 54.19464288
# 34
# 450
# 460
# 470
# 480
# 490

# %%
<class 'list'>: [array([ 0, 22, 13, 18, 10, 32, 19, 34, 23,  6,  0]), array([ 0, 48, 49,  5, 28,  2, 16, 39, 23,  0]), array([ 0, 43, 41, 12,  6, 35, 26, 22,  0]), array([ 0, 23, 39, 46, 19, 41,  6, 38, 22,  0])]

# %%
for i in range(len(a)):
    x.plota_rotas(x.mapa,a[i])
    print(b[i], c[i], d[i])
# Out:
# 35.58657598 31.3142455192 33.58375599
# 41.83553333 34.0178790187 44.5275601
# 27.15519921 34.1834821815 45.64715333
# 28.71404198 34.2519070755 30.99638672

# %%
for i in range(len(a)):
    x.plota_rotas(a[i])
    print(b[i], c[i], d[i])
# Out:
# 65.73778795 21.908728704 18.9558813667
# 65.73778795 21.908728704 18.9558813667
# 64.29725702 24.3107501247 22.0879834387
# 64.29725702 21.3699554061 19.1471887201
