# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from GA_SnakSack import GA_SnakSack

# %%
x = GA_SnakSack()

a,b,c,d,e = x.ga(size_generation=2000,
                 size_population=300,
                 num_generation_limit = 300,
                 max_weight=100,
                 max_coust=50,
                 towns_list='./novas_cidades_3.txt',
                 weight_list='./novos_premios_3.txt',
                 begin_deposit=0)
# Out:
# 0
# 10
# 20
# 30
# 40
# [ 89.  89.  95.  95.]
# [ 44.120998    48.43619205  54.52497552  54.68977795]
# [ 45.637006    32.69142385  26.42507343  25.93066614]
# 2
# 50
# 60
# 70
# 80
# 90
# [ 89.  89.  87.  89.]
# [ 44.120998    44.90901614  44.37169695  46.19355136]
# [ 45.637006    43.27295159  40.88490916  39.41934591]
# 52
# 100
# 110
# 120
# 130
# 140
# [ 89.  89.  88.  87.]
# [ 44.120998    44.90901614  44.341132    44.37169695]
# [ 45.637006    43.27295159  42.97660401  40.88490916]
# 102
# 150
# 160
# 170
# 180
# 190
# [ 89.  88.  78.  77.]
# [ 43.61706014  43.36512424  37.50409779  37.14780662]
# [ 47.14881958  45.90462728  43.48770663  42.55658014]
# 28
# 200
# 210
# 220
# 230
# 240
# [ 83.  88.  78.  77.]
# [ 39.36512424  43.36512424  37.50409779  37.14780662]
# [ 47.90462728  45.90462728  43.48770663  42.55658014]
# 44
# 250
# 260
# 270
# 280
# 290
# [ 83.  88.  78.  77.]
# [ 39.36512424  43.36512424  37.50409779  37.14780662]
# ...

# %%
<class 'list'>: [array([ 0, 22, 13, 18, 10, 32, 19, 34, 23,  6,  0]), array([ 0, 48, 49,  5, 28,  2, 16, 39, 23,  0]), array([ 0, 43, 41, 12,  6, 35, 26, 22,  0]), array([ 0, 23, 39, 46, 19, 41,  6, 38, 22,  0])]

# %%
for i in range(len(a)):
    x.plota_rotas(x.mapa,a[i])
    print(b[i], c[i], d[i])
# Out:
# 83.0 39.3651242385 17.0
# 88.0 43.3651242385 17.0
# 83.0 40.7148426986 17.0
# 77.0 37.147806619 15.0

# %%
for i in range(len(a)):
    x.plota_rotas(a[i])
    print(b[i], c[i], d[i])
