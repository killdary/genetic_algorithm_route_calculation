# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from GA_SnakSack import GA_SnakSack

# %%
x = GA_SnakSack()

a,b,c,d,e = x.ga(size_generation=2000,
                 size_population=900,
                 num_generation_limit = 400,
                 max_weight=100,
                 max_coust=400,
                 towns_list='./novas_cidades_3.txt',
                 weight_list='./novos_premios_3.txt',
                 begin_deposit=0)
# Out:
# 0
# 10
# 20
# 30
# 40
# 149.0
# 78.7559917651
# 61.7320247048
# 6
# 50
# 60
# 70
# 80
# 90
# 149.0
# 78.7559917651
# 61.7320247048
# 56
# 100
# 110
# 120
# 130
# 140
# 149.0
# 78.7559917651
# 61.7320247048
# 106
# 150
# 160
# 170
# 180
# 190
# 149.0
# 78.7559917651
# 61.7320247048
# 156
# 200
# 210
# 220
# 230
# 240
# 149.0
# 78.7559917651
# 61.7320247048
# 206
# 250
# 260
# 270
# 280
# 290
# 149.0
# 74.054209538
# 75.8373713861
# 25
# 300
# 310
# 320
# 330
# 340
# 149.0
# 74.054209538
# 75.8373713861
# 75
# 350
# 360
# 370
# 380
# 390
# 149.0
# 74.054209538
# 75.8373713861
# 125
# 400
# 410
# 420
# 430
# 440
# 149.0
# 74.054209538
# 75.8373713861
# 175
# 450
# 460
# 470
# 480
# 490
# 149.0
# 74.054209538
# 75.8373713861
# 225
# 500
# 510
# 520
# 530
# 540
# 149.0
# 74.054209538
# 75.8373713861
# 275
# 550
# 560
# 570
# 580
# 590
# 149.0
# 74.054209538
# 75.8373713861
# 325
# 600
# 610
# 620
# 630
# 640
# 149.0
# 74.054209538
# 75.8373713861
# 375
# 650
# 660
# 670

# %%
for i in range(len(a)):
    x.plota_rotas(x.mapa,a[i])
    print(b[i], c[i], d[i], e[i])
# Out:
# 149.0 74.054209538 31.0 75.8373713861
# 149.0 74.4709478704 31.0 74.5871563887
# 149.0 81.800702682 31.0 52.597891954
# 149.0 74.1477646931 31.0 75.5567059206

# %%
for i in range(len(a)):
    x.plota_rotas(x.mapa,a[i])
    print(b[i], c[i], d[i], e[i])
# Out:
# 145.0 72.9657221951 31.0 71.1028334147
# 145.0 73.0592773503 31.0 70.8221679492
# 145.0 74.2416503379 31.0 67.2750489863
# 145.0 73.7344116896 31.0 68.7967649312
